# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
train_df=pd.read_excel('Data_Train.xlsx')

# %%
train_df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
test_df=pd.read_excel('Test_set.xlsx')

# %%
test_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
train_df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
train_df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
final=train_df.append(test_df)

# %%
final
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
 final.tail()
# is se apan last wala part dekh skte hai df ka
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
# now 1st we need to convert this date into date time formag i.e date alag month alag and year alag 
# and this thing is called creating a derived feature
#inorder to do that we need to split the date using / 
final['Date_of_Journey'].str.split('/')
# Out:
# 0       [24, 03, 2019]
# 1        [1, 05, 2019]
# 2        [9, 06, 2019]
# 3       [12, 05, 2019]
# 4       [01, 03, 2019]
#              ...
# 2666     [6, 06, 2019]
# 2667    [27, 03, 2019]
# 2668     [6, 03, 2019]
# 2669     [6, 03, 2019]
# 2670    [15, 06, 2019]
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
#and from the above matrix we need to choose the 1st thing i.e 0th index thingy 
final['Date_of_Journey'].str.split('/')[0]
# is se to wo aagya jis ka row =0 hai we need 0th columns
# Out:
# 0    [24, 03, 2019]
# 0     [6, 06, 2019]
# Name: Date_of_Journey, dtype: object

# %%
final['Date_of_Journey'].str.split('/').str[0]
# Out:
# 0       24
# 1        1
# 2        9
# 3       12
# 4       01
#         ..
# 2666     6
# 2667    27
# 2668     6
# 2669     6
# 2670    15
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
final['Date']=final['Date_of_Journey'].str.split('/').str[0]
final['Month']=final['Date_of_Journey'].str.split('/').str[1]
final['Year']=final['Date_of_Journey'].str.split('/').str[2]

# %%
final
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
# df["Date"]=df['Date_of_Journey'].apply(lambda x:x.split("/")[0])
# df["Month"]=df['Date_of_Journey'].apply(lambda x:x.split("/")[1])
# df["Year"]=df['Date_of_Journey'].apply(lambda x:x.split("/")[2])
# can use lambda function too article is linked in saved messages for refrences

# %%
final
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
final['Date']=final['Date'].astype(int)
final['Month']=final['Month'].astype(int)
final['Year']=final['Year'].astype(int)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int32
#  12  Month            13354 non-null  int32
#  13  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.9+ MB

# %%
final.drop('Date_of_Journey',inplace=True,axis=1)

# %%
final
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
final['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0       01:10
# 1       13:15
# 2       04:25
# 3       23:30
# 4       21:35
#         ...
# 2666    20:25
# 2667    16:55
# 2668    04:25
# 2669    19:15
# 2670    19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final['Arrival_Time'].str.split(' ').str[1]
# Out:
# 0        22
# 1       NaN
# 2        10
# 3       NaN
# 4       NaN
#        ...
# 2666     07
# 2667    NaN
# 2668     07
# 2669    NaN
# 2670    NaN
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final['Arrival_date']=final['Arrival_Time'].str.split(' ').str[1]

# %%
final['Arrival_date']=final['Arrival_date'].fillna(final['Date'])

# %%
final['Arrival_date']
# Out:
# 0       22
# 1        1
# 2       10
# 3       12
# 4        1
#         ..
# 2666    07
# 2667    27
# 2668    07
# 2669     6
# 2670    15
# Name: Arrival_date, Length: 13354, dtype: object

# %%
# or using lambda function
final['Arrival_Time']=final['Arrival_Time'].apply(lambda x : x.split(' ')[0])
final['Arrival_Time']
# Out:
# 0       01:10
# 1       13:15
# 2       04:25
# 3       23:30
# 4       21:35
#         ...
# 2666    20:25
# 2667    16:55
# 2668    04:25
# 2669    19:15
# 2670    19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final['Arrival_hour']=final['Arrival_Time'].apply(lambda x : x.split(':')[0])

# %%
final['Arrival_Time'].apply(lambda x : x.split(':')[0])
# Out:
# 0       01
# 1       13
# 2       04
# 3       23
# 4       21
#         ..
# 2666    20
# 2667    16
# 2668    04
# 2669    19
# 2670    19
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final['Arrival_hour']
# Out:
# 0       01
# 1       13
# 2       04
# 3       23
# 4       21
#         ..
# 2666    20
# 2667    16
# 2668    04
# 2669    19
# 2670    19
# Name: Arrival_hour, Length: 13354, dtype: object

# %%
final['Arrival_min']=final['Arrival_Time'].apply(lambda x : x.split(':')[1])

# %%
final['Arrival_min']
# Out:
# 0       10
# 1       15
# 2       25
# 3       30
# 4       35
#         ..
# 2666    25
# 2667    55
# 2668    25
# 2669    15
# 2670    15
# Name: Arrival_min, Length: 13354, dtype: object

# %%
final['Arrival_min']=final['Arrival_min'].astype(int)

# %%
final['Arrival_hour']=final['Arrival_hour'].astype(int)

# %%
final
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
final.drop('Arrival_Time',axis=1,inplace=True)

# %%
#now for departure time 
#arrival date 
final['Arrival_date']=final['Arrival_date'].astype(int)

# %%
final
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Duration         13354 non-null  object
#  6   Total_Stops      13353 non-null  object
#  7   Additional_Info  13354 non-null  object
#  8   Price            10683 non-null  float64
#  9   Date             13354 non-null  int32
#  10  Month            13354 non-null  int32
#  11  Year             13354 non-null  int32
#  12  Arrival_date     13354 non-null  int32
#  13  Arrival_hour     13354 non-null  int32
#  14  Arrival_min      13354 non-null  int32
# dtypes: float64(1), int32(6), object(8)
# memory usage: 1.8+ MB

# %%
final['Dept_hour']=final['Dep_Time'].str.split(':').str[0]
final['Dept_min']=final['Dep_Time'].str.split(':').str[1]
final['Dept_hour']=final['Dept_hour'].astype(int)
final['Dept_min']=final['Dept_min'].astype(int)
final.drop('Dep_Time',axis=1,inplace=True)

# %%
final['Route'].unique()
# Out:
# array(['BLR → DEL', 'CCU → IXR → BBI → BLR', 'DEL → LKO → BOM → COK',
#        'CCU → NAG → BLR', 'BLR → NAG → DEL', 'CCU → BLR',
#        'BLR → BOM → DEL', 'DEL → BOM → COK', 'DEL → BLR → COK',
#        'MAA → CCU', 'CCU → BOM → BLR', 'DEL → AMD → BOM → COK',
#        'DEL → PNQ → COK', 'DEL → CCU → BOM → COK', 'BLR → COK → DEL',
#        'DEL → IDR → BOM → COK', 'DEL → LKO → COK',
#        'CCU → GAU → DEL → BLR', 'DEL → NAG → BOM → COK',
#        'CCU → MAA → BLR', 'DEL → HYD → COK', 'CCU → HYD → BLR',
#        'DEL → COK', 'CCU → DEL → BLR', 'BLR → BOM → AMD → DEL',
#        'BOM → DEL → HYD', 'DEL → MAA → COK', 'BOM → HYD',
#        'DEL → BHO → BOM → COK', 'DEL → JAI → BOM → COK',
#        'DEL → ATQ → BOM → COK', 'DEL → JDH → BOM → COK',
#        'CCU → BBI → BOM → BLR', 'BLR → MAA → DEL',
#        'DEL → GOI → BOM → COK', 'DEL → BDQ → BOM → COK',
#        'CCU → JAI → BOM → BLR', 'CCU → BBI → BLR', 'BLR → HYD → DEL',
#        'DEL → TRV → COK', 'CCU → IXR → DEL → BLR',
# ...

# %%
final['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
final['Total_Stops']=final['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})
#since its just one single record it wont matter that much to replace nan with anything

# %%
#in order to see a specific thingy 
final[final['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration  Total_Stops  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m          NaN
#
#      Additional_Info   Price  Date  Month  Year  Arrival_date  Arrival_hour  \
# 9039         No info  7480.0     6      5  2019             7             9
#
#       Arrival_min  Dept_hour  Dept_min
# 9039           25          9        45

# %%
final
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
# ...

# %%
final.drop('Route',axis=1,inplace=True)

# %%
final
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  Date  Month  Year  Arrival_date  Arrival_hour  \
# ...

# %%
final['Duration'].str.split(' ')
# Out:
# 0        [2h, 50m]
# 1        [7h, 25m]
# 2            [19h]
# 3        [5h, 25m]
# 4        [4h, 45m]
#            ...
# 2666    [23h, 55m]
# 2667     [2h, 35m]
# 2668     [6h, 35m]
# 2669    [15h, 15m]
# 2670    [14h, 20m]
# Name: Duration, Length: 13354, dtype: object

# %%
final['Duration'].str.split(' ').str[0]
# Out:
# 0        2h
# 1        7h
# 2       19h
# 3        5h
# 4        4h
#        ...
# 2666    23h
# 2667     2h
# 2668     6h
# 2669    15h
# 2670    14h
# Name: Duration, Length: 13354, dtype: object

# %%
type(final['Duration'].str.split(' ').str[0])
# Out:
# pandas.core.series.Series

# %%
#as we can see its becoming a series now we google  pandas series split 
# and see what we find in the documentation
final['Duration'].str.split(' ').str[0].str.split("h")
# Out:
# 0        [2, ]
# 1        [7, ]
# 2       [19, ]
# 3        [5, ]
# 4        [4, ]
#          ...
# 2666    [23, ]
# 2667     [2, ]
# 2668     [6, ]
# 2669    [15, ]
# 2670    [14, ]
# Name: Duration, Length: 13354, dtype: object

# %%
final['Duration'].str.split(' ').str[0].str.split("h").str[0]
# Out:
# 0        2
# 1        7
# 2       19
# 3        5
# 4        4
#         ..
# 2666    23
# 2667     2
# 2668     6
# 2669    15
# 2670    14
# Name: Duration, Length: 13354, dtype: object

# %%
 final['duration_hour']=final['Duration'].str.split(' ').str[0].str.split("h").str[0]

# %%
final['duration_hour'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %%
final[final['duration_hour']=="5m"]
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474  Air India  Mumbai   Hyderabad       5m          2.0         No info
# 2660  Air India  Mumbai   Hyderabad       5m          2.0         No info
#
#         Price  Date  Month  Year  Arrival_date  Arrival_hour  Arrival_min  \
# 6474  17327.0     6      3  2019             6            16           55
# 2660      NaN    12      3  2019            12            16           55
#
#       Dept_hour  Dept_min duration_hour
# 6474         16        50            5m
# 2660         16        50            5m

# %%
final['duration_hour'] = final['duration_hour'].replace(['5m'],'5')

# %%
final[final['duration_hour']=="5m"]
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Duration, Total_Stops, Additional_Info, Price, Date, Month, Year, Arrival_date, Arrival_hour, Arrival_min, Dept_hour, Dept_min, duration_hour]
# Index: []

# %%
# alternatively could have droped it 
# final_df.drop(6474,axis=0,inplace=True)
# final_df.drop(2660,axis=0,inplace=True)

# %%
 final['duration_hour']=final['duration_hour'].astype(int)

# %%
 final['duration_hour']
# Out:
# 0        2
# 1        7
# 2       19
# 3        5
# 4        4
#         ..
# 2666    23
# 2667     2
# 2668     6
# 2669    15
# 2670    14
# Name: duration_hour, Length: 13354, dtype: int32

# %%
final['Duration'].str.split(' ').str[1]
# Out:
# 0       50m
# 1       25m
# 2       NaN
# 3       25m
# 4       45m
#        ...
# 2666    55m
# 2667    35m
# 2668    35m
# 2669    15m
# 2670    20m
# Name: Duration, Length: 13354, dtype: object

# %%
final['Duration'].str.split(' ').str[1].str.split('m').str[0]
# Out:
# 0        50
# 1        25
# 2       NaN
# 3        25
# 4        45
#        ...
# 2666     55
# 2667     35
# 2668     35
# 2669     15
# 2670     20
# Name: Duration, Length: 13354, dtype: object

# %%
final['duration_min']=final['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
final['duration_min'].isnull().sum()
# Out:
# 1286

# %%
final['duration_min']=final['duration_min'].fillna(0)

# %%
final['duration_min'].isnull().sum()
# Out:
# 0

# %%
final['duration_min'].astype(int)
# Out:
# 0       50
# 1       25
# 2        0
# 3       25
# 4       45
#         ..
# 2666    55
# 2667    35
# 2668    35
# 2669    15
# 2670    20
# Name: duration_min, Length: 13354, dtype: int32

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13353 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   Date             13354 non-null  int32
#  8   Month            13354 non-null  int32
#  9   Year             13354 non-null  int32
#  10  Arrival_date     13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int32
#  12  Arrival_min      13354 non-null  int32
#  13  Dept_hour        13354 non-null  int32
#  14  Dept_min         13354 non-null  int32
#  15  duration_hour    13354 non-null  int32
#  16  duration_min     13354 non-null  object
# ...

# %%
final['duration_min']=final['duration_min'].astype(int)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13353 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   Date             13354 non-null  int32
#  8   Month            13354 non-null  int32
#  9   Year             13354 non-null  int32
#  10  Arrival_date     13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int32
#  12  Arrival_min      13354 non-null  int32
#  13  Dept_hour        13354 non-null  int32
#  14  Dept_min         13354 non-null  int32
#  15  duration_hour    13354 non-null  int32
#  16  duration_min     13354 non-null  int32
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13353 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   Date             13354 non-null  int32
#  8   Month            13354 non-null  int32
#  9   Year             13354 non-null  int32
#  10  Arrival_date     13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int32
#  12  Arrival_min      13354 non-null  int32
#  13  Dept_hour        13354 non-null  int32
#  14  Dept_min         13354 non-null  int32
#  15  duration_hour    13354 non-null  int32
#  16  duration_min     13354 non-null  int32
# ...

# %%
final['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
final['Airline']=labelencoder.fit_transform(final['Airline'])
final['Source']=labelencoder.fit_transform(final['Source'])
final['Destination']=labelencoder.fit_transform(final['Destination'])
final['Additional_Info']=labelencoder.fit_transform(final['Additional_Info'])

# %%
final
# Out:
#       Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 0           3       0            5   2h 50m          0.0                8
# 1           1       3            0   7h 25m          2.0                8
# 2           4       2            1      19h          2.0                8
# 3           3       3            0   5h 25m          1.0                8
# 4           3       0            5   4h 45m          1.0                8
# ...       ...     ...          ...      ...          ...              ...
# 2666        1       3            0  23h 55m          1.0                8
# 2667        3       3            0   2h 35m          0.0                8
# 2668        4       2            1   6h 35m          1.0                8
# 2669        1       2            1  15h 15m          1.0                8
# 2670        6       2            1  14h 20m          1.0                8
#
#         Price  Date  Month  Year  Arrival_date  Arrival_hour  Arrival_min  \
# ...

# %%
final.drop('Duration',axis=1, inplace=True)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  int64
#  1   Source           13354 non-null  int64
#  2   Destination      13354 non-null  int32
#  3   Total_Stops      13353 non-null  float64
#  4   Additional_Info  13354 non-null  int32
#  5   Price            10683 non-null  float64
#  6   Date             13354 non-null  int32
#  7   Month            13354 non-null  int32
#  8   Year             13354 non-null  int32
#  9   Arrival_date     13354 non-null  int32
#  10  Arrival_hour     13354 non-null  int32
#  11  Arrival_min      13354 non-null  int32
#  12  Dept_hour        13354 non-null  int32
#  13  Dept_min         13354 non-null  int32
#  14  duration_hour    13354 non-null  int32
#  15  duration_min     13354 non-null  int32
# dtypes: float64(2), int32(12), int64(2)
# ...

# %%
#whenever we have test data dont do it with get dummies 
final['Airline']
# Out:
# 0       3
# 1       1
# 2       4
# 3       3
# 4       3
#        ..
# 2666    1
# 2667    3
# 2668    4
# 2669    1
# 2670    6
# Name: Airline, Length: 13354, dtype: int64

# %%
#as we can see the data is in the form of series 
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()

# %%
#now we can apply tthis one hot enconding
final['Airline']=ohe.fit_transform(final['Airline'])
final['Source']=ohe.fit_transform(final['Source'])
final['Destination']=ohe.fit_transform(final['Destination'])
final['Additional_Info']=ohe.fit_transform(final['Additional_Info'])
#it shows an error coz for one hot encoding  we need to pass data in form array and as we saw the data was in the form of a series
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15480/3128314722.py in <module>
#       1 #now we can apply tthis one hot enconding
# ----> 2 final['Airline']=ohe.fit_transform(final['Airline'])
#       3 final['Source']=ohe.fit_transform(final['Source'])
#       4 final['Destination']=ohe.fit_transform(final['Destination'])
#       5 final['Additional_Info']=ohe.fit_transform(final['Additional_Info'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     449         """
#     450         self._validate_keywords()
# --> 451         return super().fit_transform(X, y)
#     452
#     453     def transform(self, X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
# ...

# %%
# pd.get_dummies(final_df,columns=["Airline", "Source", "Destination"] ,drop_first = True)
# another way to get dummies if one hot encoding is not working
